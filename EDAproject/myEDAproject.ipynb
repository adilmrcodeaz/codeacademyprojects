# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("myEDAproject.csv")
df
# Out:
#       productCode                   productName               customerName  \
# 0        S12_1108             2001 Ferrari Enzo     Euro+ Shopping Channel
# 1        S12_1108             2001 Ferrari Enzo     Euro+ Shopping Channel
# 2        S12_1108             2001 Ferrari Enzo     Euro+ Shopping Channel
# 3        S12_1108             2001 Ferrari Enzo     Euro+ Shopping Channel
# 4        S12_1108             2001 Ferrari Enzo     Euro+ Shopping Channel
# ...           ...                           ...                        ...
# 35531    S50_1341  1930 Buick Marquette Phaeton  The Sharp Gifts Warehouse
# 35532    S50_1341  1930 Buick Marquette Phaeton  The Sharp Gifts Warehouse
# 35533    S50_1341  1930 Buick Marquette Phaeton  The Sharp Gifts Warehouse
# 35534    S50_1341  1930 Buick Marquette Phaeton  The Sharp Gifts Warehouse
# 35535    S50_1341  1930 Buick Marquette Phaeton  The Sharp Gifts Warehouse
#
#         orderDate  orderLineNumber  total_price
# ...

# %%
df.shape
# Out:
# (35536, 6)

# %%
df.columns
# Out:
# Index(['productCode', 'productName', 'customerName', 'orderDate',
#        'orderLineNumber', 'total_price'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       productCode                   productName               customerName  \
# 0        S12_1108             2001 Ferrari Enzo     Euro+ Shopping Channel
# 1        S12_1108             2001 Ferrari Enzo     Euro+ Shopping Channel
# 2        S12_1108             2001 Ferrari Enzo     Euro+ Shopping Channel
# 3        S12_1108             2001 Ferrari Enzo     Euro+ Shopping Channel
# 4        S12_1108             2001 Ferrari Enzo     Euro+ Shopping Channel
# ...           ...                           ...                        ...
# 35531    S50_1341  1930 Buick Marquette Phaeton  The Sharp Gifts Warehouse
# 35532    S50_1341  1930 Buick Marquette Phaeton  The Sharp Gifts Warehouse
# 35533    S50_1341  1930 Buick Marquette Phaeton  The Sharp Gifts Warehouse
# 35534    S50_1341  1930 Buick Marquette Phaeton  The Sharp Gifts Warehouse
# 35535    S50_1341  1930 Buick Marquette Phaeton  The Sharp Gifts Warehouse
#
# ...

# %%
df.describe()
# Out:
#        orderLineNumber   total_price
# count      35536.00000  35536.000000
# mean           7.18553    365.611144
# std            4.36505    342.698705
# min            1.00000     36.660000
# 25%            3.00000    168.720000
# 50%            7.00000    254.100000
# 75%           10.00000    400.710000
# max           18.00000   2620.410000

# %%
g =sns.countplot(x="productName", data=df.head(100));
g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %%
ax = sns.boxplot(x='productCode', y='total_price', data=df.head(1000))
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
g =sns.countplot(x="orderLineNumber", data=df.head(100));
g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Veri setini yükleme
df = pd.read_csv('myEDAproject.csv')

# Grafik oluşturma
sns.scatterplot(data=df.head(1000), x='orderDate', y='total_price')

# x eksenindeki etiketleri döndürme
plt.xticks(rotation=90)

# Grafik gösterme
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Veri setini yükleme
df = pd.read_csv('myEDAproject.csv')

# Subplots oluşturma
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

# İlk çizgi grafiği
sns.lineplot(data=df.head(50), x='productCode', y='orderDate', ax=ax1)

# İkinci çizgi grafiği
sns.lineplot(data=df.head(50), x='productCode', y='orderLineNumber', ax=ax2)

# x eksenindeki etiketleri döndürme
plt.xticks(rotation=180)

# Grafikleri gösterme
plt.show()
